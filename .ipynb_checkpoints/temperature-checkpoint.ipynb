# %% [markdown]
# CHICAGO TEMPERTURE

# %%
# We will start off by cleaning the data from the Chicago_Energy_Benchmarking_-_2019_Data_Reported_in_2020.csv

# %%
# we will be importing a few libraries that can help us with this

# %%
import pandas as pd
import numpy as np

# %%
# Reading data from the .csv file into a pandasdataframe

# %%
df = pd.read_csv('Chicago_Energy_Benchmarking_-_2019_Data_Reported_in_2020.csv')


file = pd.ExcelFile('CMAP-2019-Local-Emissions-SummariesRaw-Data.xlsx')
df2 = pd.read_excel(file,'Data')
df2.head()



citiesInCook = df2.loc[df2['COUNTY'] == 'Cook']
citiesInCook



#df.head()
# Out:
#             ID                 GEO                    TYPE COUNTY  \
# 2    1701010.0               Alsip            Municipality   Cook
# 4    1702154.0   Arlington Heights            Municipality   Cook
# 7    1703844.0          Barrington            Municipality   Cook
# 8    1703883.0    Barrington Hills            Municipality   Cook
# 12   1704572.0        Bedford Park            Municipality   Cook
# ..         ...                 ...                     ...    ...
# 364       73.0  Washington Heights  Chicago Community Area   Cook
# 365       74.0     Mount Greenwood  Chicago Community Area   Cook
# 366       75.0         Morgan Park  Chicago Community Area   Cook
# 367       76.0              O'Hare  Chicago Community Area   Cook
# 368       77.0           Edgewater  Chicago Community Area   Cook
#
#              AREA    POP   JOBS  INCOME  HOUSEHOLDS     SF_HU  ...  \
# 2     4240.248966  19063  14978   63312        7692  0.565857  ...
# 4    10643.621901  77676  38228   96340       31782  0.631671  ...
# 7     3075.304068  10722   6512  117931        4102  0.760940  ...
# 8    17713.277438   4114    453  178162        1466  1.000000  ...
# 12    3865.456866    602  25647   86944         208  0.928251  ...
# ..            ...    ...    ...     ...         ...       ...  ...
# 364   1828.185337  25065   1587   51800        9538  0.764841  ...
# 365   1735.176534  18628   2859  102256        6850  0.863720  ...
# 366   2109.213554  21186   3228   63501        8175  0.757707  ...
# 367   8536.170959  13418  44965   53509        6158  0.124000  ...
# 368   1111.664633  56296   7057   55768       30466  0.085233  ...
#
#        RES_NG_BTU  NONRES_NG_BTU  RES_ELE_KWH_PER NONRES_ELE_KWH_PER  \
# 2    6.621046e+05   2.468743e+06      2956.171641       1.781415e+04
# 4    3.336972e+06   2.365643e+06      3133.980313       5.078854e+03
# 7    1.015983e+06   5.981142e+05      3654.172220       8.319938e+03
# 8    5.796839e+05   3.134174e+04     10362.325960       1.239368e+03
# 12   2.968833e+04   6.552661e+06      2741.272281       1.057985e+06
# ..            ...            ...              ...                ...
# 364  6.991398e+05   9.291573e+05      2697.121105       2.700094e+03
# 365  5.195921e+05   6.905383e+05      3121.742896       1.129284e+03
# 366  5.909426e+05   7.853631e+05      2865.185744       1.921748e+03
# 367  3.742692e+05   4.974040e+05      2303.682792       1.529252e+03
# 368  1.570268e+06   2.086888e+06      2258.310454       2.999279e+03
#
#      RES_NG_BTU_PER  NONRES_NG_BTU_PER  RES_ELE_KWH_HH  RES_NG_BTU_HH  \
# 2         34.732447         129.504446     7326.248050      86.077046
# 4         42.960148          30.455269     7659.525984     104.995672
# 7         94.756812          55.783828     9551.446744     247.679799
# 8        140.905177           7.618314    29079.542292     395.418758
# 12        49.316166       10884.818606     7933.874582     142.732365
# ..              ...                ...             ...            ...
# 364       27.893070          37.069910     7087.789945      73.300461
# 365       27.893070          37.069910     8489.317762      75.852863
# 366       27.893070          37.069910     7425.299716      72.286554
# 367       27.893070          37.069910     5019.619309      60.777722
# 368       27.893070          37.069910     4172.974637      51.541662
#
#       SOLAR_POT  SOLSMART
# 2    181.917500       NaN
# 4    201.810500       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 12   236.749000       NaN
# ..          ...       ...
# 364   59.429149       NaN
# 365   38.903250       NaN
# 366   51.065306       NaN
# 367   42.870804       NaN
# 368   63.347500       NaN
#
# [197 rows x 55 columns]
